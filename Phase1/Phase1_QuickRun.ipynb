# %%
import cv2
import numpy as np
from skimage.metrics import structural_similarity as ssim
import glob
import os
import bm3d

from Phase1.utilities.median_inpainting import *


# Define denoiser and dataset options
denoiser_options = ['BM3D']  # These are two denoisers used in the TIP paper.
dataset_options = ['classics', 'BSD68']

denoiser_choice_index = 0
dataset_choice_index = 0

denoiser_choice = denoiser_options[denoiser_choice_index]
dataset_choice = dataset_options[dataset_choice_index]

images_folder = f'./Phase1/test_sets/{dataset_choice}'

ext = ['*.jpg', '*.png', '*.bmp']
images_list = []

# Iterate over each extension
for ext_type in ext:
    # Use glob to find files matching the extension in the directory
    images_list.extend(glob.glob(os.path.join(images_folder, ext_type)))

# Get the total number of images found
N_images = len(images_list)

all_results_PSNR = np.zeros((3, N_images))
all_results_ssim = np.zeros((3, N_images))

output_log = open('./Phase1/images/output_log.txt', 'w')

for scenario_ind in range(0, 2):
    for image_ind in range(N_images):
        # Read image
        img_name = images_list[image_ind].split('/')[-1]
        X0 = cv2.imread(f'{images_folder}/{img_name}')

        # Convert to grayscale
        if len(X0.shape) > 2:
            X0 = cv2.cvtColor(X0, cv2.COLOR_BGR2GRAY)

        # Initialize parameters
        M, N = X0.shape
        n = N * M
        p = int(0.8 * n) if dataset_choice == 'classics' else int(0.5 * n)
        X0 = X0.astype(float)

        # Define parameters based on scenario
        if scenario_ind == 0:
            sig_e = 0
            maxIter = 150
            delta = 5
        elif scenario_ind == 1:
            sig_e = 10
            maxIter = 75
            delta = 0
        else:
            sig_e = 12
            maxIter = 75
            delta = 0

        # Create missing pixels
        np.random.seed(0)
        missing_pixels_ind = np.random.choice(np.random.permutation(np.arange(n)),p)
        Y_clean = X0.copy()
        Y_clean.flat[missing_pixels_ind] = 0

        # Add noise
        noise = sig_e * np.random.randn(M, N)
        Y = Y_clean + noise
        Y.flat[missing_pixels_ind] = 0

        # Run inpainting
        X_median_init = median_inpainting(Y,missing_pixels_ind)
        Y_tilde = X_median_init
        X_tilde = X_median_init
        sigma_alg = sig_e + delta

        for k in range(maxIter):
            # Estimate X_tilde
            # For denoising, use preferred method
            # Here, I'm assuming a simple median filter as a placeholder
            X_tilde = bm3d.bm3d(Y_tilde, sigma_alg, 'np')

            # Estimate Y_tilde
            Y_tilde = Y.copy()
            Y_tilde.flat[missing_pixels_ind] = X_tilde.flat[missing_pixels_ind]

            # Compute PSNR
            PSNR = 10 * np.log10(255 ** 2 / np.mean((X0 - np.clip(X_tilde, 0, 255)) ** 2))
            print(f'IDBP: finished iteration {k}, PSNR for X_tilde = {PSNR}')
            output_log.write(f'IDBP: finished iteration {k}, PSNR for X_tilde = {PSNR}\n')

        if sig_e == 0:
            # In the noiseless case, take the last Y_tilde as the estimation
            X_tilde = Y_tilde
            PSNR = 10 * np.log10(255 ** 2 / np.mean((X0 - np.clip(X_tilde, 0, 255)) ** 2))
            print(f'IDBP (noiseless case): finished iteration {k}, PSNR for X_tilde = {PSNR}')
            output_log.write(f'IDBP (noiseless case): finished iteration {k}, PSNR for X_tilde = {PSNR}\n')

        # Compute SSIM
        ssim_res = ssim(X_tilde.astype(np.uint8), X0.astype(np.uint8))

        all_results_PSNR[scenario_ind - 1, image_ind] = PSNR
        all_results_ssim[scenario_ind - 1, image_ind] = ssim_res
        print(f'scenario_ind={scenario_ind}, image_ind={image_ind}, PSNR={PSNR}, SSIM={ssim_res}')
        output_log.write(f'scenario_ind={scenario_ind}, image_ind={image_ind}, PSNR={PSNR}, SSIM={ssim_res}\n')

        # Display original, observed, and inpainted images
        # cv2.imshow('Original Image', X0.astype(np.uint8))
        # cv2.imshow('Observed Image', Y.astype(np.uint8))
        # cv2.imshow('Inpainted Image', X_tilde.astype(np.uint8))
        # cv2.waitKey(0)
        # cv2.destroyAllWindows()

        # Save images
        folder_path = './Phase1/images/'
        cv2.imwrite(f'{folder_path}/original_image({scenario_ind},{image_ind}).png', X0.astype(np.uint8))
        cv2.imwrite(f'{folder_path}/observed_image({scenario_ind},{image_ind}).png', Y.astype(np.uint8))
        cv2.imwrite(f'{folder_path}/inpainted_image({scenario_ind},{image_ind}).png', X_tilde.astype(np.uint8))

output_log.close()
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /content/Phase1/utilities/median_inpainting.py:37: RuntimeWarning: All-NaN slice encountered
#   median_val = np.nanmedian(neighbors_NaN)
# IDBP: finished iteration 0, PSNR for X_tilde = 24.128082497612628
# IDBP: finished iteration 1, PSNR for X_tilde = 24.31163099410956
# IDBP: finished iteration 2, PSNR for X_tilde = 24.47802074670333
# IDBP: finished iteration 3, PSNR for X_tilde = 24.63152326358488
# IDBP: finished iteration 4, PSNR for X_tilde = 24.77487981271961
# IDBP: finished iteration 5, PSNR for X_tilde = 24.91042787806933
# IDBP: finished iteration 6, PSNR for X_tilde = 25.039569210651518
# IDBP: finished iteration 7, PSNR for X_tilde = 25.163643485675617
# IDBP: finished iteration 8, PSNR for X_tilde = 25.283897353537675
# IDBP: finished iteration 9, PSNR for X_tilde = 25.400774612211436
# IDBP: finished iteration 10, PSNR for X_tilde = 25.51495420303049
# IDBP: finished iteration 11, PSNR for X_tilde = 25.626793599712528
# IDBP: finished iteration 12, PSNR for X_tilde = 25.736761899878957
# IDBP: finished iteration 13, PSNR for X_tilde = 25.845041199263573
# IDBP: finished iteration 14, PSNR for X_tilde = 25.951801302687898
# IDBP: finished iteration 15, PSNR for X_tilde = 26.056903934864263
# IDBP: finished iteration 16, PSNR for X_tilde = 26.160506581027924
# IDBP: finished iteration 17, PSNR for X_tilde = 26.262742996646633
# IDBP: finished iteration 18, PSNR for X_tilde = 26.3633895480857
# IDBP: finished iteration 19, PSNR for X_tilde = 26.462552187318032
# IDBP: finished iteration 20, PSNR for X_tilde = 26.560253736246136
# IDBP: finished iteration 21, PSNR for X_tilde = 26.656408228824976
# IDBP: finished iteration 22, PSNR for X_tilde = 26.750963008951235
# IDBP: finished iteration 23, PSNR for X_tilde = 26.84449484445521
# IDBP: finished iteration 24, PSNR for X_tilde = 26.936907661660683
# IDBP: finished iteration 25, PSNR for X_tilde = 27.027656594641883
# IDBP: finished iteration 26, PSNR for X_tilde = 27.117026399931433
# IDBP: finished iteration 27, PSNR for X_tilde = 27.205289917027642
# IDBP: finished iteration 28, PSNR for X_tilde = 27.29246563592648
# IDBP: finished iteration 29, PSNR for X_tilde = 27.378160187982555
# IDBP: finished iteration 30, PSNR for X_tilde = 27.462410039170013
# IDBP: finished iteration 31, PSNR for X_tilde = 27.545271051190085
# IDBP: finished iteration 32, PSNR for X_tilde = 27.626526421920428
# IDBP: finished iteration 33, PSNR for X_tilde = 27.706157834739006
# IDBP: finished iteration 34, PSNR for X_tilde = 27.784811390195678
# IDBP: finished iteration 35, PSNR for X_tilde = 27.8623305347557
# IDBP: finished iteration 36, PSNR for X_tilde = 27.938742809421754
# IDBP: finished iteration 37, PSNR for X_tilde = 28.01358249374517
# IDBP: finished iteration 38, PSNR for X_tilde = 28.087644627920348
# IDBP: finished iteration 39, PSNR for X_tilde = 28.16073968116087
# IDBP: finished iteration 40, PSNR for X_tilde = 28.2322348345767
# IDBP: finished iteration 41, PSNR for X_tilde = 28.302627779505315
# IDBP: finished iteration 42, PSNR for X_tilde = 28.372155351673122
# IDBP: finished iteration 43, PSNR for X_tilde = 28.440729663205076
# IDBP: finished iteration 44, PSNR for X_tilde = 28.508478158095482
# IDBP: finished iteration 45, PSNR for X_tilde = 28.575450176685564
# IDBP: finished iteration 46, PSNR for X_tilde = 28.64191262690361
# IDBP: finished iteration 47, PSNR for X_tilde = 28.707854105499745
# IDBP: finished iteration 48, PSNR for X_tilde = 28.773168240885852
# IDBP: finished iteration 49, PSNR for X_tilde = 28.838112252564247
# IDBP: finished iteration 50, PSNR for X_tilde = 28.902466731592995
# IDBP: finished iteration 51, PSNR for X_tilde = 28.966452622825024
# IDBP: finished iteration 52, PSNR for X_tilde = 29.029980777166354
# IDBP: finished iteration 53, PSNR for X_tilde = 29.09305777799617
# IDBP: finished iteration 54, PSNR for X_tilde = 29.155640959801335
# IDBP: finished iteration 55, PSNR for X_tilde = 29.21756946376184
# IDBP: finished iteration 56, PSNR for X_tilde = 29.279496958481538
# IDBP: finished iteration 57, PSNR for X_tilde = 29.340731882185963
# IDBP: finished iteration 58, PSNR for X_tilde = 29.40202900776503
# IDBP: finished iteration 59, PSNR for X_tilde = 29.462662693286713
# IDBP: finished iteration 60, PSNR for X_tilde = 29.523094959258582
# IDBP: finished iteration 61, PSNR for X_tilde = 29.583044859262305
# IDBP: finished iteration 62, PSNR for X_tilde = 29.64264623708736
# IDBP: finished iteration 63, PSNR for X_tilde = 29.702062198229726
# IDBP: finished iteration 64, PSNR for X_tilde = 29.76118315429684
# IDBP: finished iteration 65, PSNR for X_tilde = 29.819820522823708
# IDBP: finished iteration 66, PSNR for X_tilde = 29.87847533635561
# IDBP: finished iteration 67, PSNR for X_tilde = 29.936962365104577
# IDBP: finished iteration 68, PSNR for X_tilde = 29.99482492919736
# IDBP: finished iteration 69, PSNR for X_tilde = 30.052441248506078
# IDBP: finished iteration 70, PSNR for X_tilde = 30.109997725423057
# IDBP: finished iteration 71, PSNR for X_tilde = 30.167067048032767
# IDBP: finished iteration 72, PSNR for X_tilde = 30.223578709353202
# IDBP: finished iteration 73, PSNR for X_tilde = 30.279678667891346
# IDBP: finished iteration 74, PSNR for X_tilde = 30.33546921909779
# IDBP: finished iteration 75, PSNR for X_tilde = 30.391294279253167
# IDBP: finished iteration 76, PSNR for X_tilde = 30.44663935980533
# IDBP: finished iteration 77, PSNR for X_tilde = 30.501584137841583
# IDBP: finished iteration 78, PSNR for X_tilde = 30.556464357200646
# IDBP: finished iteration 79, PSNR for X_tilde = 30.611409907210415
# IDBP: finished iteration 80, PSNR for X_tilde = 30.66608349504678
# IDBP: finished iteration 81, PSNR for X_tilde = 30.720258685253746
# IDBP: finished iteration 82, PSNR for X_tilde = 30.774077760941108
# IDBP: finished iteration 83, PSNR for X_tilde = 30.827750624376012
# IDBP: finished iteration 84, PSNR for X_tilde = 30.881045469205883
# IDBP: finished iteration 85, PSNR for X_tilde = 30.933638180520347
# IDBP: finished iteration 86, PSNR for X_tilde = 30.986061192959646
# IDBP: finished iteration 87, PSNR for X_tilde = 31.038513816057005
# IDBP: finished iteration 88, PSNR for X_tilde = 31.09029158400252
# IDBP: finished iteration 89, PSNR for X_tilde = 31.141763245911346
# IDBP: finished iteration 90, PSNR for X_tilde = 31.193170635231734
# IDBP: finished iteration 91, PSNR for X_tilde = 31.244370758759487
# IDBP: finished iteration 92, PSNR for X_tilde = 31.29535681582084
# IDBP: finished iteration 93, PSNR for X_tilde = 31.345989062612812
# IDBP: finished iteration 94, PSNR for X_tilde = 31.396114376407795
# IDBP: finished iteration 95, PSNR for X_tilde = 31.44623244421057
# IDBP: finished iteration 96, PSNR for X_tilde = 31.496205027863663
# IDBP: finished iteration 97, PSNR for X_tilde = 31.54603556003543
# IDBP: finished iteration 98, PSNR for X_tilde = 31.595318448357673
# IDBP: finished iteration 99, PSNR for X_tilde = 31.64461808213946
# IDBP: finished iteration 100, PSNR for X_tilde = 31.693375521171596
# IDBP: finished iteration 101, PSNR for X_tilde = 31.741902629183475
# IDBP: finished iteration 102, PSNR for X_tilde = 31.7903055748602
# IDBP: finished iteration 103, PSNR for X_tilde = 31.838422844577213
# IDBP: finished iteration 104, PSNR for X_tilde = 31.886716061808723
# IDBP: finished iteration 105, PSNR for X_tilde = 31.93481874335244
# IDBP: finished iteration 106, PSNR for X_tilde = 31.982821618626865
# IDBP: finished iteration 107, PSNR for X_tilde = 32.03088221729197
# IDBP: finished iteration 108, PSNR for X_tilde = 32.07852064187566
# IDBP: finished iteration 109, PSNR for X_tilde = 32.12592270746046
# IDBP: finished iteration 110, PSNR for X_tilde = 32.17325174076614
# IDBP: finished iteration 111, PSNR for X_tilde = 32.220442984283
# IDBP: finished iteration 112, PSNR for X_tilde = 32.267596206618066
# IDBP: finished iteration 113, PSNR for X_tilde = 32.31465254396758
# IDBP: finished iteration 114, PSNR for X_tilde = 32.361681886208935
# IDBP: finished iteration 115, PSNR for X_tilde = 32.40876804084483
# IDBP: finished iteration 116, PSNR for X_tilde = 32.45593844301762
# IDBP: finished iteration 117, PSNR for X_tilde = 32.50350267070751
# IDBP: finished iteration 118, PSNR for X_tilde = 32.55025888788742
# IDBP: finished iteration 119, PSNR for X_tilde = 32.59687702122997
# IDBP: finished iteration 120, PSNR for X_tilde = 32.643311149727566
# IDBP: finished iteration 121, PSNR for X_tilde = 32.68951522937512
# IDBP: finished iteration 122, PSNR for X_tilde = 32.73512662363959
# IDBP: finished iteration 123, PSNR for X_tilde = 32.78018516581807
# IDBP: finished iteration 124, PSNR for X_tilde = 32.82520668265609
# IDBP: finished iteration 125, PSNR for X_tilde = 32.86981053523419
# IDBP: finished iteration 126, PSNR for X_tilde = 32.91434566872055
# IDBP: finished iteration 127, PSNR for X_tilde = 32.958408335439955
# IDBP: finished iteration 128, PSNR for X_tilde = 33.00200561715232
# IDBP: finished iteration 129, PSNR for X_tilde = 33.04535566161336
# IDBP: finished iteration 130, PSNR for X_tilde = 33.08826639740863
# IDBP: finished iteration 131, PSNR for X_tilde = 33.13109664891423
# IDBP: finished iteration 132, PSNR for X_tilde = 33.173439722869674
# IDBP: finished iteration 133, PSNR for X_tilde = 33.21556989429633
# IDBP: finished iteration 134, PSNR for X_tilde = 33.25676347185072
# IDBP: finished iteration 135, PSNR for X_tilde = 33.29807930980329
# IDBP: finished iteration 136, PSNR for X_tilde = 33.33853242551426
# IDBP: finished iteration 137, PSNR for X_tilde = 33.378830447358496
# IDBP: finished iteration 138, PSNR for X_tilde = 33.41805979555388
# IDBP: finished iteration 139, PSNR for X_tilde = 33.45677293741112
# IDBP: finished iteration 140, PSNR for X_tilde = 33.49510608448509
# IDBP: finished iteration 141, PSNR for X_tilde = 33.532466200570916
# IDBP: finished iteration 142, PSNR for X_tilde = 33.56948150257457
# IDBP: finished iteration 143, PSNR for X_tilde = 33.605812064099815
# IDBP: finished iteration 144, PSNR for X_tilde = 33.64185617802693
# IDBP: finished iteration 145, PSNR for X_tilde = 33.67704851979966
# IDBP: finished iteration 146, PSNR for X_tilde = 33.71130478655719
# IDBP: finished iteration 147, PSNR for X_tilde = 33.7448984248983
# IDBP: finished iteration 148, PSNR for X_tilde = 33.77731076878546
# IDBP: finished iteration 149, PSNR for X_tilde = 33.80901293438489
# IDBP (noiseless case): finished iteration 149, PSNR for X_tilde = 34.321013446441754
# scenario_ind=0, image_ind=0, PSNR=34.321013446441754, SSIM=0.9635826461119168
# IDBP: finished iteration 0, PSNR for X_tilde = 27.18655509623519
# IDBP: finished iteration 1, PSNR for X_tilde = 27.556286973228477
# IDBP: finished iteration 2, PSNR for X_tilde = 27.885779009199666
# IDBP: finished iteration 3, PSNR for X_tilde = 28.184819774678704
# IDBP: finished iteration 4, PSNR for X_tilde = 28.459285711430123
# IDBP: finished iteration 5, PSNR for X_tilde = 28.712871571166474
# IDBP: finished iteration 6, PSNR for X_tilde = 28.9487462702675
# IDBP: finished iteration 7, PSNR for X_tilde = 29.167905020369915
# IDBP: finished iteration 8, PSNR for X_tilde = 29.372458840011788
# IDBP: finished iteration 9, PSNR for X_tilde = 29.563292535845275
# IDBP: finished iteration 10, PSNR for X_tilde = 29.741335816709793
# IDBP: finished iteration 11, PSNR for X_tilde = 29.907633136923394
# IDBP: finished iteration 12, PSNR for X_tilde = 30.063073232294744
# IDBP: finished iteration 13, PSNR for X_tilde = 30.20874033648721
# IDBP: finished iteration 14, PSNR for X_tilde = 30.344196114059546
# IDBP: finished iteration 15, PSNR for X_tilde = 30.4706129097696
# IDBP: finished iteration 16, PSNR for X_tilde = 30.58866365719139
# IDBP: finished iteration 17, PSNR for X_tilde = 30.69904753846618
# IDBP: finished iteration 18, PSNR for X_tilde = 30.80202855557339
# IDBP: finished iteration 19, PSNR for X_tilde = 30.899094723179058
# IDBP: finished iteration 20, PSNR for X_tilde = 30.989527965110256
# IDBP: finished iteration 21, PSNR for X_tilde = 31.074783520170797
# IDBP: finished iteration 22, PSNR for X_tilde = 31.15464080678286
# IDBP: finished iteration 23, PSNR for X_tilde = 31.229369798394867
# IDBP: finished iteration 24, PSNR for X_tilde = 31.300138226747794
# IDBP: finished iteration 25, PSNR for X_tilde = 31.366646503913334
# IDBP: finished iteration 26, PSNR for X_tilde = 31.428970664812116
# IDBP: finished iteration 27, PSNR for X_tilde = 31.487606375693172
# IDBP: finished iteration 28, PSNR for X_tilde = 31.542483257147342
# IDBP: finished iteration 29, PSNR for X_tilde = 31.59441507543827
# IDBP: finished iteration 30, PSNR for X_tilde = 31.64359192607431
# IDBP: finished iteration 31, PSNR for X_tilde = 31.689502095680226
# IDBP: finished iteration 32, PSNR for X_tilde = 31.73285393032176
# IDBP: finished iteration 33, PSNR for X_tilde = 31.77398156192044
# IDBP: finished iteration 34, PSNR for X_tilde = 31.813257849276873
# IDBP: finished iteration 35, PSNR for X_tilde = 31.850466961590644
# IDBP: finished iteration 36, PSNR for X_tilde = 31.885935158089058
# IDBP: finished iteration 37, PSNR for X_tilde = 31.91916588702105
# IDBP: finished iteration 38, PSNR for X_tilde = 31.95052498851018
# IDBP: finished iteration 39, PSNR for X_tilde = 31.980409650057567
# IDBP: finished iteration 40, PSNR for X_tilde = 32.00894741288256
# IDBP: finished iteration 41, PSNR for X_tilde = 32.03639124477586
# IDBP: finished iteration 42, PSNR for X_tilde = 32.06265648138266
# IDBP: finished iteration 43, PSNR for X_tilde = 32.08795119087951
# IDBP: finished iteration 44, PSNR for X_tilde = 32.11235267733447
# IDBP: finished iteration 45, PSNR for X_tilde = 32.13575364479074
# IDBP: finished iteration 46, PSNR for X_tilde = 32.158173028221015
# IDBP: finished iteration 47, PSNR for X_tilde = 32.1798146100054
# IDBP: finished iteration 48, PSNR for X_tilde = 32.20074545237396
# IDBP: finished iteration 49, PSNR for X_tilde = 32.22078393695206
# IDBP: finished iteration 50, PSNR for X_tilde = 32.23998362678278
# IDBP: finished iteration 51, PSNR for X_tilde = 32.25841892603902
# IDBP: finished iteration 52, PSNR for X_tilde = 32.27562623331161
# IDBP: finished iteration 53, PSNR for X_tilde = 32.292234360191074
# IDBP: finished iteration 54, PSNR for X_tilde = 32.30807139743465
# IDBP: finished iteration 55, PSNR for X_tilde = 32.323669589163046
# IDBP: finished iteration 56, PSNR for X_tilde = 32.338698630913576
# IDBP: finished iteration 57, PSNR for X_tilde = 32.35339358838546
# IDBP: finished iteration 58, PSNR for X_tilde = 32.36742403714506
# IDBP: finished iteration 59, PSNR for X_tilde = 32.38097562129569
# IDBP: finished iteration 60, PSNR for X_tilde = 32.3940471425021
# IDBP: finished iteration 61, PSNR for X_tilde = 32.40660925337477
# IDBP: finished iteration 62, PSNR for X_tilde = 32.41859282207977
# IDBP: finished iteration 63, PSNR for X_tilde = 32.42996032994297
# IDBP: finished iteration 64, PSNR for X_tilde = 32.441187729794244
# IDBP: finished iteration 65, PSNR for X_tilde = 32.45175751950909
# IDBP: finished iteration 66, PSNR for X_tilde = 32.46214750676835
# IDBP: finished iteration 67, PSNR for X_tilde = 32.47251450072134
# IDBP: finished iteration 68, PSNR for X_tilde = 32.4822588656607
# IDBP: finished iteration 69, PSNR for X_tilde = 32.49182699768853
# IDBP: finished iteration 70, PSNR for X_tilde = 32.50126562640267
# IDBP: finished iteration 71, PSNR for X_tilde = 32.51032296212148
# IDBP: finished iteration 72, PSNR for X_tilde = 32.5189414137659
# IDBP: finished iteration 73, PSNR for X_tilde = 32.52711379952198
# IDBP: finished iteration 74, PSNR for X_tilde = 32.534933417772805
# IDBP: finished iteration 75, PSNR for X_tilde = 32.54276940153744
# IDBP: finished iteration 76, PSNR for X_tilde = 32.55011845908709
# IDBP: finished iteration 77, PSNR for X_tilde = 32.55768617625595
# IDBP: finished iteration 78, PSNR for X_tilde = 32.56442572244237
# IDBP: finished iteration 79, PSNR for X_tilde = 32.57146144302365
# IDBP: finished iteration 80, PSNR for X_tilde = 32.57811684340128
# IDBP: finished iteration 81, PSNR for X_tilde = 32.58479693893165
# IDBP: finished iteration 82, PSNR for X_tilde = 32.59094685323311
# IDBP: finished iteration 83, PSNR for X_tilde = 32.59751247645067
# IDBP: finished iteration 84, PSNR for X_tilde = 32.60360354855275
# IDBP: finished iteration 85, PSNR for X_tilde = 32.60943756638973
# IDBP: finished iteration 86, PSNR for X_tilde = 32.615113915197654
# IDBP: finished iteration 87, PSNR for X_tilde = 32.62023650469863
# IDBP: finished iteration 88, PSNR for X_tilde = 32.62562423435257
# IDBP: finished iteration 89, PSNR for X_tilde = 32.630186243693075
# IDBP: finished iteration 90, PSNR for X_tilde = 32.63500778580061
# IDBP: finished iteration 91, PSNR for X_tilde = 32.639727914010194
# IDBP: finished iteration 92, PSNR for X_tilde = 32.64455199883851
# IDBP: finished iteration 93, PSNR for X_tilde = 32.648920901480324
# IDBP: finished iteration 94, PSNR for X_tilde = 32.65304287894119
# IDBP: finished iteration 95, PSNR for X_tilde = 32.65718308030746
# IDBP: finished iteration 96, PSNR for X_tilde = 32.661136602250956
# IDBP: finished iteration 97, PSNR for X_tilde = 32.66459506395678
# IDBP: finished iteration 98, PSNR for X_tilde = 32.66815199401323
# IDBP: finished iteration 99, PSNR for X_tilde = 32.671812830416314
# IDBP: finished iteration 100, PSNR for X_tilde = 32.675371556381386
# IDBP: finished iteration 101, PSNR for X_tilde = 32.6788935776879
# IDBP: finished iteration 102, PSNR for X_tilde = 32.682277032673106
# IDBP: finished iteration 103, PSNR for X_tilde = 32.68532856878438
# IDBP: finished iteration 104, PSNR for X_tilde = 32.68864101085042
# IDBP: finished iteration 105, PSNR for X_tilde = 32.69144533042006
# IDBP: finished iteration 106, PSNR for X_tilde = 32.693985172143954
# IDBP: finished iteration 107, PSNR for X_tilde = 32.696376803052104
# IDBP: finished iteration 108, PSNR for X_tilde = 32.6988016248507
# IDBP: finished iteration 109, PSNR for X_tilde = 32.701028684280644
# IDBP: finished iteration 110, PSNR for X_tilde = 32.703062383138295
# IDBP: finished iteration 111, PSNR for X_tilde = 32.705314481936924
# IDBP: finished iteration 112, PSNR for X_tilde = 32.70735166884503
# IDBP: finished iteration 113, PSNR for X_tilde = 32.709583560409754
# IDBP: finished iteration 114, PSNR for X_tilde = 32.71192942372497
# IDBP: finished iteration 115, PSNR for X_tilde = 32.71413212585217
# IDBP: finished iteration 116, PSNR for X_tilde = 32.71613201194217
# IDBP: finished iteration 117, PSNR for X_tilde = 32.71829106769034
# IDBP: finished iteration 118, PSNR for X_tilde = 32.720506140718435
# IDBP: finished iteration 119, PSNR for X_tilde = 32.72241751301224
# IDBP: finished iteration 120, PSNR for X_tilde = 32.72462259730273
# IDBP: finished iteration 121, PSNR for X_tilde = 32.726673576161566
# IDBP: finished iteration 122, PSNR for X_tilde = 32.72867718793014
# IDBP: finished iteration 123, PSNR for X_tilde = 32.730533932704596
# IDBP: finished iteration 124, PSNR for X_tilde = 32.73236228852835
# IDBP: finished iteration 125, PSNR for X_tilde = 32.734202376043434
# IDBP: finished iteration 126, PSNR for X_tilde = 32.7358363712576
# IDBP: finished iteration 127, PSNR for X_tilde = 32.737470898200634
# IDBP: finished iteration 128, PSNR for X_tilde = 32.73921816234336
# IDBP: finished iteration 129, PSNR for X_tilde = 32.74065941753749
# IDBP: finished iteration 130, PSNR for X_tilde = 32.7422224899376
# IDBP: finished iteration 131, PSNR for X_tilde = 32.74365578092295
# IDBP: finished iteration 132, PSNR for X_tilde = 32.74516356682831
# IDBP: finished iteration 133, PSNR for X_tilde = 32.74645066021746
# IDBP: finished iteration 134, PSNR for X_tilde = 32.74782942415052
# IDBP: finished iteration 135, PSNR for X_tilde = 32.749116076369596
# IDBP: finished iteration 136, PSNR for X_tilde = 32.750304059102426
# IDBP: finished iteration 137, PSNR for X_tilde = 32.75137085699611
# IDBP: finished iteration 138, PSNR for X_tilde = 32.752613456796624
# IDBP: finished iteration 139, PSNR for X_tilde = 32.75383664623548
# IDBP: finished iteration 140, PSNR for X_tilde = 32.75514781478829
# IDBP: finished iteration 141, PSNR for X_tilde = 32.75638122235576
# IDBP: finished iteration 142, PSNR for X_tilde = 32.75719400611402
# IDBP: finished iteration 143, PSNR for X_tilde = 32.758041894230466
# IDBP: finished iteration 144, PSNR for X_tilde = 32.75863498280722
# IDBP: finished iteration 145, PSNR for X_tilde = 32.75945800264103
# IDBP: finished iteration 146, PSNR for X_tilde = 32.76004610545582
# IDBP: finished iteration 147, PSNR for X_tilde = 32.76076744721649
# IDBP: finished iteration 148, PSNR for X_tilde = 32.76156538342464
# IDBP: finished iteration 149, PSNR for X_tilde = 32.76210940483531
# IDBP (noiseless case): finished iteration 149, PSNR for X_tilde = 33.36064040826249
# scenario_ind=0, image_ind=1, PSNR=33.36064040826249, SSIM=0.9378149454182272
# IDBP: finished iteration 0, PSNR for X_tilde = 29.219033803752676
# IDBP: finished iteration 1, PSNR for X_tilde = 29.64304079792337
# IDBP: finished iteration 2, PSNR for X_tilde = 29.989882840697227
# IDBP: finished iteration 3, PSNR for X_tilde = 30.28060102613695
# IDBP: finished iteration 4, PSNR for X_tilde = 30.530008136365762
# IDBP: finished iteration 5, PSNR for X_tilde = 30.747261308607683
# IDBP: finished iteration 6, PSNR for X_tilde = 30.93806445410309
# IDBP: finished iteration 7, PSNR for X_tilde = 31.107806595158053
# IDBP: finished iteration 8, PSNR for X_tilde = 31.26017736953159
# IDBP: finished iteration 9, PSNR for X_tilde = 31.39806589882616
# IDBP: finished iteration 10, PSNR for X_tilde = 31.52355546302806
# IDBP: finished iteration 11, PSNR for X_tilde = 31.63773856381482
# IDBP: finished iteration 12, PSNR for X_tilde = 31.741670545370937
# IDBP: finished iteration 13, PSNR for X_tilde = 31.8360654144951
# IDBP: finished iteration 14, PSNR for X_tilde = 31.922664506990483
# IDBP: finished iteration 15, PSNR for X_tilde = 32.001222361508994
# IDBP: finished iteration 16, PSNR for X_tilde = 32.07313878566963
# IDBP: finished iteration 17, PSNR for X_tilde = 32.13951986240324
# IDBP: finished iteration 18, PSNR for X_tilde = 32.20029405688007
# IDBP: finished iteration 19, PSNR for X_tilde = 32.25540874743664
# IDBP: finished iteration 20, PSNR for X_tilde = 32.30641469233817
# IDBP: finished iteration 21, PSNR for X_tilde = 32.35406834748583
# IDBP: finished iteration 22, PSNR for X_tilde = 32.39834559761658
# IDBP: finished iteration 23, PSNR for X_tilde = 32.440054381705316
# IDBP: finished iteration 24, PSNR for X_tilde = 32.478797277040144
# IDBP: finished iteration 25, PSNR for X_tilde = 32.515173385885994
# IDBP: finished iteration 26, PSNR for X_tilde = 32.54866887717991
# IDBP: finished iteration 27, PSNR for X_tilde = 32.57984564649157
# IDBP: finished iteration 28, PSNR for X_tilde = 32.609058074924455
# IDBP: finished iteration 29, PSNR for X_tilde = 32.635751515017844
# IDBP: finished iteration 30, PSNR for X_tilde = 32.66069200795186
# IDBP: finished iteration 31, PSNR for X_tilde = 32.68414006903556
# IDBP: finished iteration 32, PSNR for X_tilde = 32.70560958621353
# IDBP: finished iteration 33, PSNR for X_tilde = 32.726007164262704
# IDBP: finished iteration 34, PSNR for X_tilde = 32.74471445530854
# IDBP: finished iteration 35, PSNR for X_tilde = 32.76250911618248
# IDBP: finished iteration 36, PSNR for X_tilde = 32.77906263615907
# IDBP: finished iteration 37, PSNR for X_tilde = 32.79432446189751
# IDBP: finished iteration 38, PSNR for X_tilde = 32.80873974484769
# IDBP: finished iteration 39, PSNR for X_tilde = 32.822237644705545
# IDBP: finished iteration 40, PSNR for X_tilde = 32.83471634341045
# IDBP: finished iteration 41, PSNR for X_tilde = 32.84636590867192
# IDBP: finished iteration 42, PSNR for X_tilde = 32.85725114796848
# IDBP: finished iteration 43, PSNR for X_tilde = 32.867697671137655
# IDBP: finished iteration 44, PSNR for X_tilde = 32.877462726701985
# IDBP: finished iteration 45, PSNR for X_tilde = 32.88618409904062
# IDBP: finished iteration 46, PSNR for X_tilde = 32.89506529274397
# IDBP: finished iteration 47, PSNR for X_tilde = 32.90348302173402
# IDBP: finished iteration 48, PSNR for X_tilde = 32.910958683581676
# IDBP: finished iteration 49, PSNR for X_tilde = 32.91820244039711
# IDBP: finished iteration 50, PSNR for X_tilde = 32.925028351150786
# IDBP: finished iteration 51, PSNR for X_tilde = 32.93143258057558
# IDBP: finished iteration 52, PSNR for X_tilde = 32.93768347062574
# IDBP: finished iteration 53, PSNR for X_tilde = 32.94371764121668
# IDBP: finished iteration 54, PSNR for X_tilde = 32.94929269564008
# IDBP: finished iteration 55, PSNR for X_tilde = 32.95484782548349
# IDBP: finished iteration 56, PSNR for X_tilde = 32.95991439805293
# IDBP: finished iteration 57, PSNR for X_tilde = 32.96529975723842
# IDBP: finished iteration 58, PSNR for X_tilde = 32.970071774164516
# IDBP: finished iteration 59, PSNR for X_tilde = 32.97488990482157
# IDBP: finished iteration 60, PSNR for X_tilde = 32.979425348362234
# IDBP: finished iteration 61, PSNR for X_tilde = 32.9836749405987
# IDBP: finished iteration 62, PSNR for X_tilde = 32.987549510608346
# IDBP: finished iteration 63, PSNR for X_tilde = 32.99127929307628
# IDBP: finished iteration 64, PSNR for X_tilde = 32.994668405575815
# IDBP: finished iteration 65, PSNR for X_tilde = 32.99814323587074
# IDBP: finished iteration 66, PSNR for X_tilde = 33.00143896229014
# IDBP: finished iteration 67, PSNR for X_tilde = 33.00475806627641
# IDBP: finished iteration 68, PSNR for X_tilde = 33.00726832272408
# IDBP: finished iteration 69, PSNR for X_tilde = 33.01011924037583
# IDBP: finished iteration 70, PSNR for X_tilde = 33.012728157371775
# IDBP: finished iteration 71, PSNR for X_tilde = 33.015038399143634
# IDBP: finished iteration 72, PSNR for X_tilde = 33.017119483179
# IDBP: finished iteration 73, PSNR for X_tilde = 33.01924500608173
# IDBP: finished iteration 74, PSNR for X_tilde = 33.02151703507518
# IDBP: finished iteration 75, PSNR for X_tilde = 33.02354962686438
# IDBP: finished iteration 76, PSNR for X_tilde = 33.02563574650864
# IDBP: finished iteration 77, PSNR for X_tilde = 33.027374291349304
# IDBP: finished iteration 78, PSNR for X_tilde = 33.02896703595109
# IDBP: finished iteration 79, PSNR for X_tilde = 33.03093342139046
# IDBP: finished iteration 80, PSNR for X_tilde = 33.03230702160887
# IDBP: finished iteration 81, PSNR for X_tilde = 33.033777270445846
# IDBP: finished iteration 82, PSNR for X_tilde = 33.035439594410995
# IDBP: finished iteration 83, PSNR for X_tilde = 33.037209597974034
# IDBP: finished iteration 84, PSNR for X_tilde = 33.03859782402625
# IDBP: finished iteration 85, PSNR for X_tilde = 33.03986343119715
# IDBP: finished iteration 86, PSNR for X_tilde = 33.04131594646406
# IDBP: finished iteration 87, PSNR for X_tilde = 33.042357384533545
# IDBP: finished iteration 88, PSNR for X_tilde = 33.043286513210774
# IDBP: finished iteration 89, PSNR for X_tilde = 33.0446937113263
# IDBP: finished iteration 90, PSNR for X_tilde = 33.04571575684109
# IDBP: finished iteration 91, PSNR for X_tilde = 33.04677352261035
# IDBP: finished iteration 92, PSNR for X_tilde = 33.04768694555489
# IDBP: finished iteration 93, PSNR for X_tilde = 33.048671803406954
# IDBP: finished iteration 94, PSNR for X_tilde = 33.049783572813844
# IDBP: finished iteration 95, PSNR for X_tilde = 33.050882528767936
# IDBP: finished iteration 96, PSNR for X_tilde = 33.05187914800888
# IDBP: finished iteration 97, PSNR for X_tilde = 33.05254985012597
# IDBP: finished iteration 98, PSNR for X_tilde = 33.05330316603955
# IDBP: finished iteration 99, PSNR for X_tilde = 33.05384316395564
# IDBP: finished iteration 100, PSNR for X_tilde = 33.05456452246841
# IDBP: finished iteration 101, PSNR for X_tilde = 33.05525607513813
# IDBP: finished iteration 102, PSNR for X_tilde = 33.05606520371809
# IDBP: finished iteration 103, PSNR for X_tilde = 33.056624406063634
# IDBP: finished iteration 104, PSNR for X_tilde = 33.05724544139678
# IDBP: finished iteration 105, PSNR for X_tilde = 33.05807002010424
# IDBP: finished iteration 106, PSNR for X_tilde = 33.05893007135037
# IDBP: finished iteration 107, PSNR for X_tilde = 33.05904693168682
# IDBP: finished iteration 108, PSNR for X_tilde = 33.059853086596284
# IDBP: finished iteration 109, PSNR for X_tilde = 33.06038511742389
# IDBP: finished iteration 110, PSNR for X_tilde = 33.06053803486839
# IDBP: finished iteration 111, PSNR for X_tilde = 33.06113479636463
# IDBP: finished iteration 112, PSNR for X_tilde = 33.06152527341895
# IDBP: finished iteration 113, PSNR for X_tilde = 33.06175533993813
# IDBP: finished iteration 114, PSNR for X_tilde = 33.06242269509618
# IDBP: finished iteration 115, PSNR for X_tilde = 33.063010035609956
# IDBP: finished iteration 116, PSNR for X_tilde = 33.06363712949438
# IDBP: finished iteration 117, PSNR for X_tilde = 33.06418607057465
# IDBP: finished iteration 118, PSNR for X_tilde = 33.06473613934709
# IDBP: finished iteration 119, PSNR for X_tilde = 33.065180878414864
# IDBP: finished iteration 120, PSNR for X_tilde = 33.06558688232303
# IDBP: finished iteration 121, PSNR for X_tilde = 33.065674287145356
# IDBP: finished iteration 122, PSNR for X_tilde = 33.06584377822767
# IDBP: finished iteration 123, PSNR for X_tilde = 33.06608171715641
# IDBP: finished iteration 124, PSNR for X_tilde = 33.06644989646019
# IDBP: finished iteration 125, PSNR for X_tilde = 33.06660998381581
# IDBP: finished iteration 126, PSNR for X_tilde = 33.066865329665504
# IDBP: finished iteration 127, PSNR for X_tilde = 33.06699554026781
# IDBP: finished iteration 128, PSNR for X_tilde = 33.06734417034925
# IDBP: finished iteration 129, PSNR for X_tilde = 33.06804557136411
# IDBP: finished iteration 130, PSNR for X_tilde = 33.06809680769923
# IDBP: finished iteration 131, PSNR for X_tilde = 33.06851717678167
# IDBP: finished iteration 132, PSNR for X_tilde = 33.06885203857839
# IDBP: finished iteration 133, PSNR for X_tilde = 33.069369342603984
# IDBP: finished iteration 134, PSNR for X_tilde = 33.069626818511225
# IDBP: finished iteration 135, PSNR for X_tilde = 33.07007062324005
# IDBP: finished iteration 136, PSNR for X_tilde = 33.07076576916553
# IDBP: finished iteration 137, PSNR for X_tilde = 33.071155163708184
# IDBP: finished iteration 138, PSNR for X_tilde = 33.07171358862291
# IDBP: finished iteration 139, PSNR for X_tilde = 33.07246273209411
# IDBP: finished iteration 140, PSNR for X_tilde = 33.072807954886386
# IDBP: finished iteration 141, PSNR for X_tilde = 33.073098866642425
# IDBP: finished iteration 142, PSNR for X_tilde = 33.073400111217424
# IDBP: finished iteration 143, PSNR for X_tilde = 33.073512266236406
# IDBP: finished iteration 144, PSNR for X_tilde = 33.07356060545706
# IDBP: finished iteration 145, PSNR for X_tilde = 33.073872422200175
# IDBP: finished iteration 146, PSNR for X_tilde = 33.0737815178205
# IDBP: finished iteration 147, PSNR for X_tilde = 33.07399107656685
# IDBP: finished iteration 148, PSNR for X_tilde = 33.07405937089839
# IDBP: finished iteration 149, PSNR for X_tilde = 33.07449947373997
# IDBP (noiseless case): finished iteration 149, PSNR for X_tilde = 33.93099896460741
# scenario_ind=0, image_ind=2, PSNR=33.93099896460741, SSIM=0.9229090066139207
# IDBP: finished iteration 0, PSNR for X_tilde = 29.216508013916037
# IDBP: finished iteration 1, PSNR for X_tilde = 29.56753089366197
# IDBP: finished iteration 2, PSNR for X_tilde = 29.918377289876634
# IDBP: finished iteration 3, PSNR for X_tilde = 30.265189606137387
# IDBP: finished iteration 4, PSNR for X_tilde = 30.603711941788802
# IDBP: finished iteration 5, PSNR for X_tilde = 30.93247741031562
# IDBP: finished iteration 6, PSNR for X_tilde = 31.247268559611264
# IDBP: finished iteration 7, PSNR for X_tilde = 31.549682216365458
# IDBP: finished iteration 8, PSNR for X_tilde = 31.838730644864658
# IDBP: finished iteration 9, PSNR for X_tilde = 32.11520547741602
# IDBP: finished iteration 10, PSNR for X_tilde = 32.38214106698501
# IDBP: finished iteration 11, PSNR for X_tilde = 32.64096333944097
# IDBP: finished iteration 12, PSNR for X_tilde = 32.89042949939943
# IDBP: finished iteration 13, PSNR for X_tilde = 33.13007345229698
# IDBP: finished iteration 14, PSNR for X_tilde = 33.35949904209256
# IDBP: finished iteration 15, PSNR for X_tilde = 33.57588265481656
# IDBP: finished iteration 16, PSNR for X_tilde = 33.77811592917135
# IDBP: finished iteration 17, PSNR for X_tilde = 33.96625615018401
# IDBP: finished iteration 18, PSNR for X_tilde = 34.14019953414067
# IDBP: finished iteration 19, PSNR for X_tilde = 34.30013164146965
# IDBP: finished iteration 20, PSNR for X_tilde = 34.44651330979183
# IDBP: finished iteration 21, PSNR for X_tilde = 34.58227075397237
# IDBP: finished iteration 22, PSNR for X_tilde = 34.70665179210273
# IDBP: finished iteration 23, PSNR for X_tilde = 34.82230316628785
# IDBP: finished iteration 24, PSNR for X_tilde = 34.93304926680326
# IDBP: finished iteration 25, PSNR for X_tilde = 35.03841797150243
# IDBP: finished iteration 26, PSNR for X_tilde = 35.13889039188938
# IDBP: finished iteration 27, PSNR for X_tilde = 35.23216111801438
# IDBP: finished iteration 28, PSNR for X_tilde = 35.3178371662959
# IDBP: finished iteration 29, PSNR for X_tilde = 35.395878882798556
# IDBP: finished iteration 30, PSNR for X_tilde = 35.467909860686255
# IDBP: finished iteration 31, PSNR for X_tilde = 35.533473469076235
# IDBP: finished iteration 32, PSNR for X_tilde = 35.59678944854265
# IDBP: finished iteration 33, PSNR for X_tilde = 35.65525012743266
# IDBP: finished iteration 34, PSNR for X_tilde = 35.71022308805977
# IDBP: finished iteration 35, PSNR for X_tilde = 35.761394322080264
# IDBP: finished iteration 36, PSNR for X_tilde = 35.809527972080055
# IDBP: finished iteration 37, PSNR for X_tilde = 35.85525742200285
# IDBP: finished iteration 38, PSNR for X_tilde = 35.898291255484565
# IDBP: finished iteration 39, PSNR for X_tilde = 35.93991415194933
# IDBP: finished iteration 40, PSNR for X_tilde = 35.980107560039734
# IDBP: finished iteration 41, PSNR for X_tilde = 36.01837205211345
# IDBP: finished iteration 42, PSNR for X_tilde = 36.05213281884407
# IDBP: finished iteration 43, PSNR for X_tilde = 36.083617176164196
# IDBP: finished iteration 44, PSNR for X_tilde = 36.11127671807154
# IDBP: finished iteration 45, PSNR for X_tilde = 36.13823944753078
# IDBP: finished iteration 46, PSNR for X_tilde = 36.16263533970808
# IDBP: finished iteration 47, PSNR for X_tilde = 36.183957573348565
# IDBP: finished iteration 48, PSNR for X_tilde = 36.20450931705215
# IDBP: finished iteration 49, PSNR for X_tilde = 36.22323859594186
# IDBP: finished iteration 50, PSNR for X_tilde = 36.24068441416941
# IDBP: finished iteration 51, PSNR for X_tilde = 36.25545081032779
# IDBP: finished iteration 52, PSNR for X_tilde = 36.27132614496907
# IDBP: finished iteration 53, PSNR for X_tilde = 36.28440058956063
# IDBP: finished iteration 54, PSNR for X_tilde = 36.297763778056236
# IDBP: finished iteration 55, PSNR for X_tilde = 36.309545525308586
# IDBP: finished iteration 56, PSNR for X_tilde = 36.321943672751445
# IDBP: finished iteration 57, PSNR for X_tilde = 36.331872947613164
# IDBP: finished iteration 58, PSNR for X_tilde = 36.34201744156451
# IDBP: finished iteration 59, PSNR for X_tilde = 36.35232406542289
# IDBP: finished iteration 60, PSNR for X_tilde = 36.36197097126663
# IDBP: finished iteration 61, PSNR for X_tilde = 36.37175602723484
# IDBP: finished iteration 62, PSNR for X_tilde = 36.38146814244704
# IDBP: finished iteration 63, PSNR for X_tilde = 36.390509439506545
# IDBP: finished iteration 64, PSNR for X_tilde = 36.398420671312394
# IDBP: finished iteration 65, PSNR for X_tilde = 36.406114912272656
# IDBP: finished iteration 66, PSNR for X_tilde = 36.413256836056306
# IDBP: finished iteration 67, PSNR for X_tilde = 36.4230454709169
# IDBP: finished iteration 68, PSNR for X_tilde = 36.43033725414768
# IDBP: finished iteration 69, PSNR for X_tilde = 36.43879037383356
# IDBP: finished iteration 70, PSNR for X_tilde = 36.44611146105967
# IDBP: finished iteration 71, PSNR for X_tilde = 36.45290417938472
# IDBP: finished iteration 72, PSNR for X_tilde = 36.46199353787917
# IDBP: finished iteration 73, PSNR for X_tilde = 36.46963548946865
# IDBP: finished iteration 74, PSNR for X_tilde = 36.476350644746006
# IDBP: finished iteration 75, PSNR for X_tilde = 36.48350818969215
# IDBP: finished iteration 76, PSNR for X_tilde = 36.48940859433265
# IDBP: finished iteration 77, PSNR for X_tilde = 36.49507312353987
# IDBP: finished iteration 78, PSNR for X_tilde = 36.50163731275191
# IDBP: finished iteration 79, PSNR for X_tilde = 36.506194309989674
# IDBP: finished iteration 80, PSNR for X_tilde = 36.509690404864784
# IDBP: finished iteration 81, PSNR for X_tilde = 36.512979044926425
# IDBP: finished iteration 82, PSNR for X_tilde = 36.51619153072677
# IDBP: finished iteration 83, PSNR for X_tilde = 36.51958698454074
# IDBP: finished iteration 84, PSNR for X_tilde = 36.52320996653417
# IDBP: finished iteration 85, PSNR for X_tilde = 36.526180638194596
# IDBP: finished iteration 86, PSNR for X_tilde = 36.52769845313901
# IDBP: finished iteration 87, PSNR for X_tilde = 36.5293225650794
# IDBP: finished iteration 88, PSNR for X_tilde = 36.53045043637175
# IDBP: finished iteration 89, PSNR for X_tilde = 36.53175938178062
# IDBP: finished iteration 90, PSNR for X_tilde = 36.53439750449041
# IDBP: finished iteration 91, PSNR for X_tilde = 36.53454468151389
# IDBP: finished iteration 92, PSNR for X_tilde = 36.5364093430498
# IDBP: finished iteration 93, PSNR for X_tilde = 36.53796379443262
# IDBP: finished iteration 94, PSNR for X_tilde = 36.538013365898045
# IDBP: finished iteration 95, PSNR for X_tilde = 36.53911512758605
# IDBP: finished iteration 96, PSNR for X_tilde = 36.54000943345795
# IDBP: finished iteration 97, PSNR for X_tilde = 36.5409770004939
# IDBP: finished iteration 98, PSNR for X_tilde = 36.54174067232456
# IDBP: finished iteration 99, PSNR for X_tilde = 36.543268337583726
# IDBP: finished iteration 100, PSNR for X_tilde = 36.54374463334247
# IDBP: finished iteration 101, PSNR for X_tilde = 36.546135420245946
# IDBP: finished iteration 102, PSNR for X_tilde = 36.547112965798064
# IDBP: finished iteration 103, PSNR for X_tilde = 36.54839589985612
# IDBP: finished iteration 104, PSNR for X_tilde = 36.54895003446682
# IDBP: finished iteration 105, PSNR for X_tilde = 36.55174159148636
# IDBP: finished iteration 106, PSNR for X_tilde = 36.553765933166396
# IDBP: finished iteration 107, PSNR for X_tilde = 36.556728028319135
# IDBP: finished iteration 108, PSNR for X_tilde = 36.55904103286479
# IDBP: finished iteration 109, PSNR for X_tilde = 36.56333078976583
# IDBP: finished iteration 110, PSNR for X_tilde = 36.56760011287932
# IDBP: finished iteration 111, PSNR for X_tilde = 36.57063266474984
# IDBP: finished iteration 112, PSNR for X_tilde = 36.573338783508646
# IDBP: finished iteration 113, PSNR for X_tilde = 36.57583472913788
# IDBP: finished iteration 114, PSNR for X_tilde = 36.57847034103759
# IDBP: finished iteration 115, PSNR for X_tilde = 36.58119599224959
# IDBP: finished iteration 116, PSNR for X_tilde = 36.58327569696925
# IDBP: finished iteration 117, PSNR for X_tilde = 36.583621818845124
# IDBP: finished iteration 118, PSNR for X_tilde = 36.58491595540091
# IDBP: finished iteration 119, PSNR for X_tilde = 36.58574486402473
# IDBP: finished iteration 120, PSNR for X_tilde = 36.587149277636414
# IDBP: finished iteration 121, PSNR for X_tilde = 36.587718776822584
# IDBP: finished iteration 122, PSNR for X_tilde = 36.58740305036742
# IDBP: finished iteration 123, PSNR for X_tilde = 36.58752760505158
# IDBP: finished iteration 124, PSNR for X_tilde = 36.58736784690908
# IDBP: finished iteration 125, PSNR for X_tilde = 36.58685217385716
# IDBP: finished iteration 126, PSNR for X_tilde = 36.58835447618141
# IDBP: finished iteration 127, PSNR for X_tilde = 36.587679788184346
# IDBP: finished iteration 128, PSNR for X_tilde = 36.58896644802323
# IDBP: finished iteration 129, PSNR for X_tilde = 36.589607637023086
# IDBP: finished iteration 130, PSNR for X_tilde = 36.590186197146856
# IDBP: finished iteration 131, PSNR for X_tilde = 36.59060315079471
# IDBP: finished iteration 132, PSNR for X_tilde = 36.59129101893737
# IDBP: finished iteration 133, PSNR for X_tilde = 36.59240129199402
# IDBP: finished iteration 134, PSNR for X_tilde = 36.5931478052144
# IDBP: finished iteration 135, PSNR for X_tilde = 36.59293839509293
# IDBP: finished iteration 136, PSNR for X_tilde = 36.593802589538264
# IDBP: finished iteration 137, PSNR for X_tilde = 36.59456948341909
# IDBP: finished iteration 138, PSNR for X_tilde = 36.59607439036231
# IDBP: finished iteration 139, PSNR for X_tilde = 36.596505217605795
# IDBP: finished iteration 140, PSNR for X_tilde = 36.5964078609185
# IDBP: finished iteration 141, PSNR for X_tilde = 36.59732766432442
# IDBP: finished iteration 142, PSNR for X_tilde = 36.59773236681703
# IDBP: finished iteration 143, PSNR for X_tilde = 36.59952655363282
# IDBP: finished iteration 144, PSNR for X_tilde = 36.59892311206111
# IDBP: finished iteration 145, PSNR for X_tilde = 36.600485673735605
# IDBP: finished iteration 146, PSNR for X_tilde = 36.59947295307997
# IDBP: finished iteration 147, PSNR for X_tilde = 36.600445170832536
# IDBP: finished iteration 148, PSNR for X_tilde = 36.60147894475545
# IDBP: finished iteration 149, PSNR for X_tilde = 36.60137632661461
# IDBP (noiseless case): finished iteration 149, PSNR for X_tilde = 37.84536699725398
# scenario_ind=0, image_ind=3, PSNR=37.84536699725398, SSIM=0.9531875383338392
# IDBP: finished iteration 0, PSNR for X_tilde = 24.080377347458914
# IDBP: finished iteration 1, PSNR for X_tilde = 24.18225396556659
# IDBP: finished iteration 2, PSNR for X_tilde = 24.274488611817144
# IDBP: finished iteration 3, PSNR for X_tilde = 24.359319263033605
# IDBP: finished iteration 4, PSNR for X_tilde = 24.438284960384323
# IDBP: finished iteration 5, PSNR for X_tilde = 24.51221349988805
# IDBP: finished iteration 6, PSNR for X_tilde = 24.581811858484485
# IDBP: finished iteration 7, PSNR for X_tilde = 24.648490688425724
# IDBP: finished iteration 8, PSNR for X_tilde = 24.71229670664227
# IDBP: finished iteration 9, PSNR for X_tilde = 24.774371030363312
# IDBP: finished iteration 10, PSNR for X_tilde = 24.835462154984185
# IDBP: finished iteration 11, PSNR for X_tilde = 24.89484985759132
# IDBP: finished iteration 12, PSNR for X_tilde = 24.952171114943177
# IDBP: finished iteration 13, PSNR for X_tilde = 25.00809017351276
# IDBP: finished iteration 14, PSNR for X_tilde = 25.06259574871667
# IDBP: finished iteration 15, PSNR for X_tilde = 25.11531462769726
# IDBP: finished iteration 16, PSNR for X_tilde = 25.167046013905455
# IDBP: finished iteration 17, PSNR for X_tilde = 25.218195446809965
# IDBP: finished iteration 18, PSNR for X_tilde = 25.268528454632268
# IDBP: finished iteration 19, PSNR for X_tilde = 25.318097588603337
# IDBP: finished iteration 20, PSNR for X_tilde = 25.36674110880487
# IDBP: finished iteration 21, PSNR for X_tilde = 25.4141106851579
# IDBP: finished iteration 22, PSNR for X_tilde = 25.46074797983325
# IDBP: finished iteration 23, PSNR for X_tilde = 25.50695390945394
# IDBP: finished iteration 24, PSNR for X_tilde = 25.55269246687296
# IDBP: finished iteration 25, PSNR for X_tilde = 25.59745758556053
# IDBP: finished iteration 26, PSNR for X_tilde = 25.641920941784377
# IDBP: finished iteration 27, PSNR for X_tilde = 25.686070878699834
# IDBP: finished iteration 28, PSNR for X_tilde = 25.729058446956515
# IDBP: finished iteration 29, PSNR for X_tilde = 25.77164490386258
# IDBP: finished iteration 30, PSNR for X_tilde = 25.81414915615835
# IDBP: finished iteration 31, PSNR for X_tilde = 25.856255541339106
# IDBP: finished iteration 32, PSNR for X_tilde = 25.89736507548046
# IDBP: finished iteration 33, PSNR for X_tilde = 25.93781855409255
# IDBP: finished iteration 34, PSNR for X_tilde = 25.977393288132674
# IDBP: finished iteration 35, PSNR for X_tilde = 26.01690409724153
# IDBP: finished iteration 36, PSNR for X_tilde = 26.056077066888367
# IDBP: finished iteration 37, PSNR for X_tilde = 26.094626908459002
# IDBP: finished iteration 38, PSNR for X_tilde = 26.132219747464486
# IDBP: finished iteration 39, PSNR for X_tilde = 26.169766368531093
# IDBP: finished iteration 40, PSNR for X_tilde = 26.207006022006638
# IDBP: finished iteration 41, PSNR for X_tilde = 26.2439511146696
# IDBP: finished iteration 42, PSNR for X_tilde = 26.28005645684981
# IDBP: finished iteration 43, PSNR for X_tilde = 26.31547665630093
# IDBP: finished iteration 44, PSNR for X_tilde = 26.351028225893106
# IDBP: finished iteration 45, PSNR for X_tilde = 26.385274140908578
# IDBP: finished iteration 46, PSNR for X_tilde = 26.41894561887451
# IDBP: finished iteration 47, PSNR for X_tilde = 26.452129365896177
# IDBP: finished iteration 48, PSNR for X_tilde = 26.484854303924237
# IDBP: finished iteration 49, PSNR for X_tilde = 26.517170053459576
# IDBP: finished iteration 50, PSNR for X_tilde = 26.548945524963656
# IDBP: finished iteration 51, PSNR for X_tilde = 26.58052856728052
# IDBP: finished iteration 52, PSNR for X_tilde = 26.611465838039265
# IDBP: finished iteration 53, PSNR for X_tilde = 26.64287917444039
# IDBP: finished iteration 54, PSNR for X_tilde = 26.67353823038033
# IDBP: finished iteration 55, PSNR for X_tilde = 26.704381783209495
# IDBP: finished iteration 56, PSNR for X_tilde = 26.734184619188852
# IDBP: finished iteration 57, PSNR for X_tilde = 26.763362515859427
# IDBP: finished iteration 58, PSNR for X_tilde = 26.792024074984624
# IDBP: finished iteration 59, PSNR for X_tilde = 26.82020901865148
# IDBP: finished iteration 60, PSNR for X_tilde = 26.84779140557671
# IDBP: finished iteration 61, PSNR for X_tilde = 26.874831121109914
# IDBP: finished iteration 62, PSNR for X_tilde = 26.900871199857185
# IDBP: finished iteration 63, PSNR for X_tilde = 26.926883054160136
# IDBP: finished iteration 64, PSNR for X_tilde = 26.95217276755796
# IDBP: finished iteration 65, PSNR for X_tilde = 26.977448853139194
# IDBP: finished iteration 66, PSNR for X_tilde = 27.0022889903425
# IDBP: finished iteration 67, PSNR for X_tilde = 27.02675965034473
# IDBP: finished iteration 68, PSNR for X_tilde = 27.05055967346084
# IDBP: finished iteration 69, PSNR for X_tilde = 27.07323148645284
# IDBP: finished iteration 70, PSNR for X_tilde = 27.09526463262742
# IDBP: finished iteration 71, PSNR for X_tilde = 27.11695995069188
# IDBP: finished iteration 72, PSNR for X_tilde = 27.138639947771406
# IDBP: finished iteration 73, PSNR for X_tilde = 27.159972219741363
# IDBP: finished iteration 74, PSNR for X_tilde = 27.180384785686854
# IDBP: finished iteration 75, PSNR for X_tilde = 27.20080335734119
# IDBP: finished iteration 76, PSNR for X_tilde = 27.221267004050056
# IDBP: finished iteration 77, PSNR for X_tilde = 27.241417375356257
# IDBP: finished iteration 78, PSNR for X_tilde = 27.26199567901368
# IDBP: finished iteration 79, PSNR for X_tilde = 27.2820958176726
# IDBP: finished iteration 80, PSNR for X_tilde = 27.301497381271172
# IDBP: finished iteration 81, PSNR for X_tilde = 27.320958041301935
# IDBP: finished iteration 82, PSNR for X_tilde = 27.340413411161528
# IDBP: finished iteration 83, PSNR for X_tilde = 27.35929700087876
# IDBP: finished iteration 84, PSNR for X_tilde = 27.378119283761897
# IDBP: finished iteration 85, PSNR for X_tilde = 27.396334252214693
# IDBP: finished iteration 86, PSNR for X_tilde = 27.414711139318193
# IDBP: finished iteration 87, PSNR for X_tilde = 27.433194257880082
# IDBP: finished iteration 88, PSNR for X_tilde = 27.451736237014508
# IDBP: finished iteration 89, PSNR for X_tilde = 27.469935417414998
# IDBP: finished iteration 90, PSNR for X_tilde = 27.487992814704057
# IDBP: finished iteration 91, PSNR for X_tilde = 27.505410218770177
# IDBP: finished iteration 92, PSNR for X_tilde = 27.522369624706897
# IDBP: finished iteration 93, PSNR for X_tilde = 27.539019970744366
# IDBP: finished iteration 94, PSNR for X_tilde = 27.555874055676263
# IDBP: finished iteration 95, PSNR for X_tilde = 27.57288691375473
# IDBP: finished iteration 96, PSNR for X_tilde = 27.5890401703402
# IDBP: finished iteration 97, PSNR for X_tilde = 27.604868283890376
# IDBP: finished iteration 98, PSNR for X_tilde = 27.620924044871728
# IDBP: finished iteration 99, PSNR for X_tilde = 27.637445806147028
# IDBP: finished iteration 100, PSNR for X_tilde = 27.653283117609032
# IDBP: finished iteration 101, PSNR for X_tilde = 27.66919986914981
# IDBP: finished iteration 102, PSNR for X_tilde = 27.68488470050965
# IDBP: finished iteration 103, PSNR for X_tilde = 27.700143429000263
# IDBP: finished iteration 104, PSNR for X_tilde = 27.71533544077132
# IDBP: finished iteration 105, PSNR for X_tilde = 27.730136957340275
# ...
# IDBP: finished iteration 53, PSNR for X_tilde = 27.7076182778951
# IDBP: finished iteration 54, PSNR for X_tilde = 27.736189774031814
# IDBP: finished iteration 55, PSNR for X_tilde = 27.764863958902588
# IDBP: finished iteration 56, PSNR for X_tilde = 27.7936715082787
# IDBP: finished iteration 57, PSNR for X_tilde = 27.822499588794194
# IDBP: finished iteration 58, PSNR for X_tilde = 27.85126275693791
# IDBP: finished iteration 59, PSNR for X_tilde = 27.881201986635023
# IDBP: finished iteration 60, PSNR for X_tilde = 27.911006181853523
# IDBP: finished iteration 61, PSNR for X_tilde = 27.940102780755225
# IDBP: finished iteration 62, PSNR for X_tilde = 27.96945979600464
# IDBP: finished iteration 63, PSNR for X_tilde = 27.998487490795693
# IDBP: finished iteration 64, PSNR for X_tilde = 28.027174471972028
# IDBP: finished iteration 65, PSNR for X_tilde = 28.05580044407138
# IDBP: finished iteration 66, PSNR for X_tilde = 28.083608163815832
# IDBP: finished iteration 67, PSNR for X_tilde = 28.111225916052106
# IDBP: finished iteration 68, PSNR for X_tilde = 28.138340216069352
# IDBP: finished iteration 69, PSNR for X_tilde = 28.16514061725776
# IDBP: finished iteration 70, PSNR for X_tilde = 28.191793810178623
# IDBP: finished iteration 71, PSNR for X_tilde = 28.2182672744581
# IDBP: finished iteration 72, PSNR for X_tilde = 28.244368476022565
# IDBP: finished iteration 73, PSNR for X_tilde = 28.270462096431647
# IDBP: finished iteration 74, PSNR for X_tilde = 28.296421172198837
# IDBP: finished iteration 75, PSNR for X_tilde = 28.32260161114348
# IDBP: finished iteration 76, PSNR for X_tilde = 28.34870829115786
# IDBP: finished iteration 77, PSNR for X_tilde = 28.374930818697294
# IDBP: finished iteration 78, PSNR for X_tilde = 28.401050407737735
# IDBP: finished iteration 79, PSNR for X_tilde = 28.42721642022763
# IDBP: finished iteration 80, PSNR for X_tilde = 28.45320449543241
# IDBP: finished iteration 81, PSNR for X_tilde = 28.478980581899307
# IDBP: finished iteration 82, PSNR for X_tilde = 28.504678248895917
# IDBP: finished iteration 83, PSNR for X_tilde = 28.53047688967523
# IDBP: finished iteration 84, PSNR for X_tilde = 28.555981870144798
# IDBP: finished iteration 85, PSNR for X_tilde = 28.581071457730673
# IDBP: finished iteration 86, PSNR for X_tilde = 28.605702549765525
# IDBP: finished iteration 87, PSNR for X_tilde = 28.630112225168173
# IDBP: finished iteration 88, PSNR for X_tilde = 28.654570376704143
# IDBP: finished iteration 89, PSNR for X_tilde = 28.678303723937063
# IDBP: finished iteration 90, PSNR for X_tilde = 28.701398348263858
# IDBP: finished iteration 91, PSNR for X_tilde = 28.724080855331472
# IDBP: finished iteration 92, PSNR for X_tilde = 28.746335504094127
# IDBP: finished iteration 93, PSNR for X_tilde = 28.7684884749736
# IDBP: finished iteration 94, PSNR for X_tilde = 28.790703013552946
# IDBP: finished iteration 95, PSNR for X_tilde = 28.81289663700077
# IDBP: finished iteration 96, PSNR for X_tilde = 28.83443986746724
# IDBP: finished iteration 97, PSNR for X_tilde = 28.855764794673256
# IDBP: finished iteration 98, PSNR for X_tilde = 28.87738580847202
# IDBP: finished iteration 99, PSNR for X_tilde = 28.89873553240127
# IDBP: finished iteration 100, PSNR for X_tilde = 28.919815031914933
# IDBP: finished iteration 101, PSNR for X_tilde = 28.94112667365533
# IDBP: finished iteration 102, PSNR for X_tilde = 28.962142563338098
# IDBP: finished iteration 103, PSNR for X_tilde = 28.982916707572812
# IDBP: finished iteration 104, PSNR for X_tilde = 29.003371294868636
# IDBP: finished iteration 105, PSNR for X_tilde = 29.024286408951646
# IDBP: finished iteration 106, PSNR for X_tilde = 29.044612496689037
# IDBP: finished iteration 107, PSNR for X_tilde = 29.064875481408777
# IDBP: finished iteration 108, PSNR for X_tilde = 29.084966269378217
# IDBP: finished iteration 109, PSNR for X_tilde = 29.104779991864707
# IDBP: finished iteration 110, PSNR for X_tilde = 29.12428053382978
# IDBP: finished iteration 111, PSNR for X_tilde = 29.143657733721355
# IDBP: finished iteration 112, PSNR for X_tilde = 29.16338403469863
# IDBP: finished iteration 113, PSNR for X_tilde = 29.18316202912517
# IDBP: finished iteration 114, PSNR for X_tilde = 29.20291244807465
# IDBP: finished iteration 115, PSNR for X_tilde = 29.22253489750105
# IDBP: finished iteration 116, PSNR for X_tilde = 29.242354384491254
# IDBP: finished iteration 117, PSNR for X_tilde = 29.26203420125531
# IDBP: finished iteration 118, PSNR for X_tilde = 29.280378444957122
# IDBP: finished iteration 119, PSNR for X_tilde = 29.29864755050385
# IDBP: finished iteration 120, PSNR for X_tilde = 29.316500642112047
# IDBP: finished iteration 121, PSNR for X_tilde = 29.334208133517656
# IDBP: finished iteration 122, PSNR for X_tilde = 29.35199460400094
# IDBP: finished iteration 123, PSNR for X_tilde = 29.37000265800492
# IDBP: finished iteration 124, PSNR for X_tilde = 29.387628840859954
# IDBP: finished iteration 125, PSNR for X_tilde = 29.405422282361783
# IDBP: finished iteration 126, PSNR for X_tilde = 29.423272898770463
# IDBP: finished iteration 127, PSNR for X_tilde = 29.441234783017624
# IDBP: finished iteration 128, PSNR for X_tilde = 29.459015667877438
# IDBP: finished iteration 129, PSNR for X_tilde = 29.47659677110993
# IDBP: finished iteration 130, PSNR for X_tilde = 29.494165364014812
# IDBP: finished iteration 131, PSNR for X_tilde = 29.51123305956576
# IDBP: finished iteration 132, PSNR for X_tilde = 29.528201869745175
# IDBP: finished iteration 133, PSNR for X_tilde = 29.54492138651354
# IDBP: finished iteration 134, PSNR for X_tilde = 29.561626785945208
# IDBP: finished iteration 135, PSNR for X_tilde = 29.57844733415861
# IDBP: finished iteration 136, PSNR for X_tilde = 29.595424682657985
# IDBP: finished iteration 137, PSNR for X_tilde = 29.612432608930753
# IDBP: finished iteration 138, PSNR for X_tilde = 29.62942381807349
# IDBP: finished iteration 139, PSNR for X_tilde = 29.646369986766537
# IDBP: finished iteration 140, PSNR for X_tilde = 29.663619598476064
# IDBP: finished iteration 141, PSNR for X_tilde = 29.68086143309271
# IDBP: finished iteration 142, PSNR for X_tilde = 29.697953529537415
# IDBP: finished iteration 143, PSNR for X_tilde = 29.71478511560447
# IDBP: finished iteration 144, PSNR for X_tilde = 29.731695918235378
# IDBP: finished iteration 145, PSNR for X_tilde = 29.748342074398764
# IDBP: finished iteration 146, PSNR for X_tilde = 29.764673716348213
# IDBP: finished iteration 147, PSNR for X_tilde = 29.780320519182464
# IDBP: finished iteration 148, PSNR for X_tilde = 29.795805993762702
# IDBP: finished iteration 149, PSNR for X_tilde = 29.81069986407052
# IDBP (noiseless case): finished iteration 149, PSNR for X_tilde = 30.029464454341138
# scenario_ind=0, image_ind=6, PSNR=30.029464454341138, SSIM=0.9505254233009389
# IDBP: finished iteration 0, PSNR for X_tilde = 30.092042307999186
# IDBP: finished iteration 1, PSNR for X_tilde = 30.505410633645113
# IDBP: finished iteration 2, PSNR for X_tilde = 30.861647738241984
# IDBP: finished iteration 3, PSNR for X_tilde = 31.177799257174023
# IDBP: finished iteration 4, PSNR for X_tilde = 31.46133789090303
# IDBP: finished iteration 5, PSNR for X_tilde = 31.718888397380756
# IDBP: finished iteration 6, PSNR for X_tilde = 31.9552014562678
# IDBP: finished iteration 7, PSNR for X_tilde = 32.173327485935324
# IDBP: finished iteration 8, PSNR for X_tilde = 32.375786205245916
# IDBP: finished iteration 9, PSNR for X_tilde = 32.56525234335789
# IDBP: finished iteration 10, PSNR for X_tilde = 32.742311205318316
# IDBP: finished iteration 11, PSNR for X_tilde = 32.9081401005775
# IDBP: finished iteration 12, PSNR for X_tilde = 33.06382970398981
# IDBP: finished iteration 13, PSNR for X_tilde = 33.21081505439201
# IDBP: finished iteration 14, PSNR for X_tilde = 33.34935424544442
# IDBP: finished iteration 15, PSNR for X_tilde = 33.48064812535115
# IDBP: finished iteration 16, PSNR for X_tilde = 33.604918222035025
# IDBP: finished iteration 17, PSNR for X_tilde = 33.72202969678188
# IDBP: finished iteration 18, PSNR for X_tilde = 33.83388117292876
# IDBP: finished iteration 19, PSNR for X_tilde = 33.940044644816346
# IDBP: finished iteration 20, PSNR for X_tilde = 34.040319899994074
# IDBP: finished iteration 21, PSNR for X_tilde = 34.135966628837274
# IDBP: finished iteration 22, PSNR for X_tilde = 34.22658506487808
# IDBP: finished iteration 23, PSNR for X_tilde = 34.31321650231347
# IDBP: finished iteration 24, PSNR for X_tilde = 34.39556429198104
# IDBP: finished iteration 25, PSNR for X_tilde = 34.47375562112946
# IDBP: finished iteration 26, PSNR for X_tilde = 34.547553709615
# IDBP: finished iteration 27, PSNR for X_tilde = 34.617719681471655
# IDBP: finished iteration 28, PSNR for X_tilde = 34.68380241350174
# IDBP: finished iteration 29, PSNR for X_tilde = 34.746230727154185
# IDBP: finished iteration 30, PSNR for X_tilde = 34.805314019335675
# IDBP: finished iteration 31, PSNR for X_tilde = 34.86135015290696
# IDBP: finished iteration 32, PSNR for X_tilde = 34.914070569298175
# IDBP: finished iteration 33, PSNR for X_tilde = 34.96409575537898
# IDBP: finished iteration 34, PSNR for X_tilde = 35.011388246061344
# IDBP: finished iteration 35, PSNR for X_tilde = 35.056183353789436
# IDBP: finished iteration 36, PSNR for X_tilde = 35.09932141854881
# IDBP: finished iteration 37, PSNR for X_tilde = 35.1398039204129
# IDBP: finished iteration 38, PSNR for X_tilde = 35.17764735744636
# IDBP: finished iteration 39, PSNR for X_tilde = 35.21309233160758
# IDBP: finished iteration 40, PSNR for X_tilde = 35.24643401904413
# IDBP: finished iteration 41, PSNR for X_tilde = 35.27784238700386
# IDBP: finished iteration 42, PSNR for X_tilde = 35.307425830134
# IDBP: finished iteration 43, PSNR for X_tilde = 35.335231652471464
# IDBP: finished iteration 44, PSNR for X_tilde = 35.36106349147362
# IDBP: finished iteration 45, PSNR for X_tilde = 35.386062162628754
# IDBP: finished iteration 46, PSNR for X_tilde = 35.409417877646646
# IDBP: finished iteration 47, PSNR for X_tilde = 35.431703447999595
# IDBP: finished iteration 48, PSNR for X_tilde = 35.45254055096897
# IDBP: finished iteration 49, PSNR for X_tilde = 35.472069039095544
# IDBP: finished iteration 50, PSNR for X_tilde = 35.49075945718265
# IDBP: finished iteration 51, PSNR for X_tilde = 35.50868288351648
# IDBP: finished iteration 52, PSNR for X_tilde = 35.5255865280635
# IDBP: finished iteration 53, PSNR for X_tilde = 35.54153928941958
# IDBP: finished iteration 54, PSNR for X_tilde = 35.55710929926034
# IDBP: finished iteration 55, PSNR for X_tilde = 35.571495756290645
# IDBP: finished iteration 56, PSNR for X_tilde = 35.58534369754094
# IDBP: finished iteration 57, PSNR for X_tilde = 35.598864596939
# IDBP: finished iteration 58, PSNR for X_tilde = 35.6118102197547
# IDBP: finished iteration 59, PSNR for X_tilde = 35.623351949260865
# IDBP: finished iteration 60, PSNR for X_tilde = 35.63494914677194
# IDBP: finished iteration 61, PSNR for X_tilde = 35.64566694507921
# IDBP: finished iteration 62, PSNR for X_tilde = 35.656276633126424
# IDBP: finished iteration 63, PSNR for X_tilde = 35.6664291726634
# IDBP: finished iteration 64, PSNR for X_tilde = 35.67645945563002
# IDBP: finished iteration 65, PSNR for X_tilde = 35.685723644080454
# IDBP: finished iteration 66, PSNR for X_tilde = 35.69510145170596
# IDBP: finished iteration 67, PSNR for X_tilde = 35.70374328867053
# IDBP: finished iteration 68, PSNR for X_tilde = 35.712460705793234
# IDBP: finished iteration 69, PSNR for X_tilde = 35.72062252239319
# IDBP: finished iteration 70, PSNR for X_tilde = 35.72848384079184
# IDBP: finished iteration 71, PSNR for X_tilde = 35.735647410084056
# IDBP: finished iteration 72, PSNR for X_tilde = 35.742763426214516
# IDBP: finished iteration 73, PSNR for X_tilde = 35.749132294477356
# IDBP: finished iteration 74, PSNR for X_tilde = 35.755345219332035
# IDBP: finished iteration 75, PSNR for X_tilde = 35.76141103758668
# IDBP: finished iteration 76, PSNR for X_tilde = 35.76721407880497
# IDBP: finished iteration 77, PSNR for X_tilde = 35.7725018567403
# IDBP: finished iteration 78, PSNR for X_tilde = 35.77776911404984
# IDBP: finished iteration 79, PSNR for X_tilde = 35.78238170554658
# IDBP: finished iteration 80, PSNR for X_tilde = 35.78668594340276
# IDBP: finished iteration 81, PSNR for X_tilde = 35.79118694969546
# IDBP: finished iteration 82, PSNR for X_tilde = 35.79530825899805
# IDBP: finished iteration 83, PSNR for X_tilde = 35.799236086161244
# IDBP: finished iteration 84, PSNR for X_tilde = 35.802648858333605
# IDBP: finished iteration 85, PSNR for X_tilde = 35.80654585901105
# IDBP: finished iteration 86, PSNR for X_tilde = 35.80992757724803
# IDBP: finished iteration 87, PSNR for X_tilde = 35.81363834780812
# IDBP: finished iteration 88, PSNR for X_tilde = 35.81719642355485
# IDBP: finished iteration 89, PSNR for X_tilde = 35.82044725772926
# IDBP: finished iteration 90, PSNR for X_tilde = 35.823759616689735
# IDBP: finished iteration 91, PSNR for X_tilde = 35.827032357417224
# IDBP: finished iteration 92, PSNR for X_tilde = 35.82974251925819
# IDBP: finished iteration 93, PSNR for X_tilde = 35.83269126038814
# IDBP: finished iteration 94, PSNR for X_tilde = 35.83514988957209
# IDBP: finished iteration 95, PSNR for X_tilde = 35.83754504614783
# IDBP: finished iteration 96, PSNR for X_tilde = 35.839662097770756
# IDBP: finished iteration 97, PSNR for X_tilde = 35.84211558650289
# IDBP: finished iteration 98, PSNR for X_tilde = 35.84418320692614
# IDBP: finished iteration 99, PSNR for X_tilde = 35.8466396557609
# IDBP: finished iteration 100, PSNR for X_tilde = 35.848670461488425
# IDBP: finished iteration 101, PSNR for X_tilde = 35.850751534886
# IDBP: finished iteration 102, PSNR for X_tilde = 35.85284896875055
# IDBP: finished iteration 103, PSNR for X_tilde = 35.85480979661735
# IDBP: finished iteration 104, PSNR for X_tilde = 35.856403499917135
# IDBP: finished iteration 105, PSNR for X_tilde = 35.8584812432272
# IDBP: finished iteration 106, PSNR for X_tilde = 35.86049049508493
# IDBP: finished iteration 107, PSNR for X_tilde = 35.86240105473208
# IDBP: finished iteration 108, PSNR for X_tilde = 35.864237790582
# IDBP: finished iteration 109, PSNR for X_tilde = 35.86591658699896
# IDBP: finished iteration 110, PSNR for X_tilde = 35.867719652859435
# IDBP: finished iteration 111, PSNR for X_tilde = 35.86936824400239
# IDBP: finished iteration 112, PSNR for X_tilde = 35.87108131970988
# IDBP: finished iteration 113, PSNR for X_tilde = 35.87220992985133
# IDBP: finished iteration 114, PSNR for X_tilde = 35.873696787889344
# IDBP: finished iteration 115, PSNR for X_tilde = 35.8751035788573
# IDBP: finished iteration 116, PSNR for X_tilde = 35.87624172815148
# IDBP: finished iteration 117, PSNR for X_tilde = 35.87750475740941
# IDBP: finished iteration 118, PSNR for X_tilde = 35.87842527472793
# IDBP: finished iteration 119, PSNR for X_tilde = 35.879282234632576
# IDBP: finished iteration 120, PSNR for X_tilde = 35.88051888475404
# IDBP: finished iteration 121, PSNR for X_tilde = 35.881810300056
# IDBP: finished iteration 122, PSNR for X_tilde = 35.88258015961776
# IDBP: finished iteration 123, PSNR for X_tilde = 35.88332152798829
# IDBP: finished iteration 124, PSNR for X_tilde = 35.88395303581288
# IDBP: finished iteration 125, PSNR for X_tilde = 35.88487515709127
# IDBP: finished iteration 126, PSNR for X_tilde = 35.88597032418921
# IDBP: finished iteration 127, PSNR for X_tilde = 35.88697291871362
# IDBP: finished iteration 128, PSNR for X_tilde = 35.88780206844949
# IDBP: finished iteration 129, PSNR for X_tilde = 35.88868227869462
# IDBP: finished iteration 130, PSNR for X_tilde = 35.88985151315062
# IDBP: finished iteration 131, PSNR for X_tilde = 35.89049057346326
# IDBP: finished iteration 132, PSNR for X_tilde = 35.89131478226905
# IDBP: finished iteration 133, PSNR for X_tilde = 35.89202835938201
# IDBP: finished iteration 134, PSNR for X_tilde = 35.89261256873043
# IDBP: finished iteration 135, PSNR for X_tilde = 35.89289166244477
# IDBP: finished iteration 136, PSNR for X_tilde = 35.89327990172828
# IDBP: finished iteration 137, PSNR for X_tilde = 35.89326876168573
# IDBP: finished iteration 138, PSNR for X_tilde = 35.89344929988199
# IDBP: finished iteration 139, PSNR for X_tilde = 35.893953028910815
